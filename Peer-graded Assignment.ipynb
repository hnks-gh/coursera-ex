# %%
# Data Science Tools and Ecosystem

# %%
In this notebook, we summarize some of the most popular languages, libraries, and tools used by data scientists, and we practice a few arithmetic expressions.

# %%
## Data Science Languages
- Python
- R
- SQL

# %%
## Data Science Libraries
- NumPy
- pandas
- Matplotlib / Seaborn
- scikit-learn
- TensorFlow / PyTorch

# %%
## Data Science Tools

| Tool            | Category        | What it’s used for            |
|-----------------|------------------|-------------------------------|
| JupyterLab      | Notebook IDE     | Interactive notebooks         |
| VS Code         | Editor/IDE       | Coding & extensions           |
| Apache Spark    | Big Data/Compute | Distributed processing        |
| Git/GitHub      | Version Control  | Collaboration & sharing       |

# %%
## Examples of Evaluating Arithmetic Expressions in Python
Below we multiply and add numbers, then convert minutes to hours.

# %%
# Multiply and add numbers
(3 * 4) + 5

# %%
# Convert minutes to hours
minutes = 200
hours = minutes / 60
hours

# %%
## Objectives
- List popular languages for Data Science
- List common libraries for Data Science
- Build a small Markdown tools table
- Evaluate simple arithmetic in Python
- Convert minutes to hours with code

# %%
## Author
Hoang Ngoc Kim Son
